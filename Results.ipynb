# %%
import pandas as pd
from pathlib import Path
from pathlib import PurePath

# %%
#pd.read_csv("data/result_2.csv")

# %%
standard =pd.read_csv("data/results/standard_results.csv")

# %%
standard
# Out:
#     Unnamed: 0                         test  \
# 0            0         data/test_oil_vacuum
# 1            0  data/test_oil_vacuum_teflon
# 2            0             data/test_data_2
# 3            0         data/test_oil_vacuum
# 4            0  data/test_oil_vacuum_teflon
# 5            0             data/test_data_2
# 6            0         data/test_oil_vacuum
# 7            0  data/test_oil_vacuum_teflon
# 8            0             data/test_data_2
# 9            0         data/test_oil_vacuum
# 10           0  data/test_oil_vacuum_teflon
# 11           0             data/test_data_2
# 12           0         data/test_oil_vacuum
# 13           0  data/test_oil_vacuum_teflon
# 14           0             data/test_data_2
# 15           0         data/test_oil_vacuum
# 16           0  data/test_oil_vacuum_teflon
# 17           0             data/test_data_2
# 18           0         data/test_oil_vacuum
# 19           0  data/test_oil_vacuum_teflon
# ...

# %%
standard[standard["test"] == "data/test_data_2"]
# Out:
#     Unnamed: 0              test  \
# 2            0  data/test_data_2
# 5            0  data/test_data_2
# 8            0  data/test_data_2
# 11           0  data/test_data_2
# 14           0  data/test_data_2
# 17           0  data/test_data_2
# 20           0  data/test_data_2
# 23           0  data/test_data_2
# 26           0  data/test_data_2
# 29           0  data/test_data_2
# 32           0  data/test_data_2
# 35           0  data/test_data_2
# 38           0  data/test_data_2
# 41           0  data/test_data_2
# 44           0  data/test_data_2
#
#                                                 model  window_size_sec  \
# 2   data/models/standard/model_train_oil_grid_0.25...             0.25
# 5   data/models/standard/model_train_oil_vacuum_gr...             0.25
# 8   data/models/standard/model_train_oil_vacuum_te...             0.25
# 11  data/models/standard/model_train_oil_grid_0.5.sav             0.50
# ...

# %%
standard[standard["test"] == "data/test_oil_vacuum"]
# Out:
#     Unnamed: 0                  test  \
# 0            0  data/test_oil_vacuum
# 3            0  data/test_oil_vacuum
# 6            0  data/test_oil_vacuum
# 9            0  data/test_oil_vacuum
# 12           0  data/test_oil_vacuum
# 15           0  data/test_oil_vacuum
# 18           0  data/test_oil_vacuum
# 21           0  data/test_oil_vacuum
# 24           0  data/test_oil_vacuum
# 27           0  data/test_oil_vacuum
# 30           0  data/test_oil_vacuum
# 33           0  data/test_oil_vacuum
# 36           0  data/test_oil_vacuum
# 39           0  data/test_oil_vacuum
# 42           0  data/test_oil_vacuum
#
#                                                 model  window_size_sec  \
# 0   data/models/standard/model_train_oil_grid_0.25...             0.25
# 3   data/models/standard/model_train_oil_vacuum_gr...             0.25
# 6   data/models/standard/model_train_oil_vacuum_te...             0.25
# 9   data/models/standard/model_train_oil_grid_0.5.sav             0.50
# ...

# %%
standard[standard["test"] == "data/test_oil_vacuum_teflon"]
# Out:
#     Unnamed: 0                         test  \
# 1            0  data/test_oil_vacuum_teflon
# 4            0  data/test_oil_vacuum_teflon
# 7            0  data/test_oil_vacuum_teflon
# 10           0  data/test_oil_vacuum_teflon
# 13           0  data/test_oil_vacuum_teflon
# 16           0  data/test_oil_vacuum_teflon
# 19           0  data/test_oil_vacuum_teflon
# 22           0  data/test_oil_vacuum_teflon
# 25           0  data/test_oil_vacuum_teflon
# 28           0  data/test_oil_vacuum_teflon
# 31           0  data/test_oil_vacuum_teflon
# 34           0  data/test_oil_vacuum_teflon
# 37           0  data/test_oil_vacuum_teflon
# 40           0  data/test_oil_vacuum_teflon
# 43           0  data/test_oil_vacuum_teflon
#
#                                                 model  window_size_sec  \
# 1   data/models/standard/model_train_oil_grid_0.25...             0.25
# 4   data/models/standard/model_train_oil_vacuum_gr...             0.25
# ...

# %%
pd.read_csv("data/svm_models/poly/results_test_data_2.csv")
# Out:
#    Unnamed: 0              test  \
# 0           0  data/test_data_2
# 1           0  data/test_data_2
# 2           0  data/test_data_2
# 3           0  data/test_data_2
# 4           0  data/test_data_2
# 5           0  data/test_data_2
# 6           0  data/test_data_2
# 7           0  data/test_data_2
# 8           0  data/test_data_2
#
#                                             model                kernel  \
# 0                model_train_oil_svm_poly_0.5.sav  data/svm_models/poly
# 1         model_train_oil_vacuum_svm_poly_0.5.sav  data/svm_models/poly
# 2  model_train_oil_vacuum_teflon_svm_poly_0.5.sav  data/svm_models/poly
# 3                  model_train_oil_svm_poly_2.sav  data/svm_models/poly
# 4           model_train_oil_vacuum_svm_poly_2.sav  data/svm_models/poly
# 5    model_train_oil_vacuum_teflon_svm_poly_2.sav  data/svm_models/poly
# 6                  model_train_oil_svm_poly_1.sav  data/svm_models/poly
# ...

# %%
pd.read_csv("data/svm_models/sigmoid/results_test_data_2.csv")
# Out:
#    Unnamed: 0              test  \
# 0           0  data/test_data_2
# 1           0  data/test_data_2
# 2           0  data/test_data_2
# 3           0  data/test_data_2
# 4           0  data/test_data_2
# 5           0  data/test_data_2
# 6           0  data/test_data_2
# 7           0  data/test_data_2
# 8           0  data/test_data_2
#
#                                                model                   kernel  \
# 0                model_train_oil_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 1         model_train_oil_vacuum_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 2  model_train_oil_vacuum_teflon_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 3                  model_train_oil_svm_sigmoid_2.sav  data/svm_models/sigmoid
# 4           model_train_oil_vacuum_svm_sigmoid_2.sav  data/svm_models/sigmoid
# 5    model_train_oil_vacuum_teflon_svm_sigmoid_2.sav  data/svm_models/sigmoid
# 6                  model_train_oil_svm_sigmoid_1.sav  data/svm_models/sigmoid
# ...

# %%
pd.read_csv("data/svm_models/rbf/results_test_data_2.csv")
# Out:
#    Unnamed: 0              test  \
# 0           0  data/test_data_2
# 1           0  data/test_data_2
# 2           0  data/test_data_2
# 3           0  data/test_data_2
# 4           0  data/test_data_2
# 5           0  data/test_data_2
# 6           0  data/test_data_2
# 7           0  data/test_data_2
# 8           0  data/test_data_2
#
#                                            model               kernel  \
# 0                model_train_oil_svm_rbf_0.5.sav  data/svm_models/rbf
# 1         model_train_oil_vacuum_svm_rbf_0.5.sav  data/svm_models/rbf
# 2  model_train_oil_vacuum_teflon_svm_rbf_0.5.sav  data/svm_models/rbf
# 3                  model_train_oil_svm_rbf_2.sav  data/svm_models/rbf
# 4           model_train_oil_vacuum_svm_rbf_2.sav  data/svm_models/rbf
# 5    model_train_oil_vacuum_teflon_svm_rbf_2.sav  data/svm_models/rbf
# 6                  model_train_oil_svm_rbf_1.sav  data/svm_models/rbf
# 7           model_train_oil_vacuum_svm_rbf_1.sav  data/svm_models/rbf
# ...

# %% [markdown]
# model that is trained on oil and vacuum pump can detect bubbles in teflon aswell

# %% [markdown]
# REPORT

# %%
pd.read_csv("data/svm_models/poly/results_test_oil_vacuum_teflon.csv")
# Out:
#    Unnamed: 0                         test  \
# 0           0  data/test_oil_vacuum_teflon
# 1           0  data/test_oil_vacuum_teflon
# 2           0  data/test_oil_vacuum_teflon
# 3           0  data/test_oil_vacuum_teflon
# 4           0  data/test_oil_vacuum_teflon
# 5           0  data/test_oil_vacuum_teflon
# 6           0  data/test_oil_vacuum_teflon
# 7           0  data/test_oil_vacuum_teflon
# 8           0  data/test_oil_vacuum_teflon
#
#                                             model                kernel  \
# 0                model_train_oil_svm_poly_0.5.sav  data/svm_models/poly
# 1         model_train_oil_vacuum_svm_poly_0.5.sav  data/svm_models/poly
# 2  model_train_oil_vacuum_teflon_svm_poly_0.5.sav  data/svm_models/poly
# 3                  model_train_oil_svm_poly_2.sav  data/svm_models/poly
# 4           model_train_oil_vacuum_svm_poly_2.sav  data/svm_models/poly
# 5    model_train_oil_vacuum_teflon_svm_poly_2.sav  data/svm_models/poly
# ...

# %%
pd.read_csv("data/svm_models/rbf/results_test_oil_vacuum_teflon.csv")
# Out:
#    Unnamed: 0                         test  \
# 0           0  data/test_oil_vacuum_teflon
# 1           0  data/test_oil_vacuum_teflon
# 2           0  data/test_oil_vacuum_teflon
# 3           0  data/test_oil_vacuum_teflon
# 4           0  data/test_oil_vacuum_teflon
# 5           0  data/test_oil_vacuum_teflon
# 6           0  data/test_oil_vacuum_teflon
# 7           0  data/test_oil_vacuum_teflon
# 8           0  data/test_oil_vacuum_teflon
#
#                                            model               kernel  \
# 0                model_train_oil_svm_rbf_0.5.sav  data/svm_models/rbf
# 1         model_train_oil_vacuum_svm_rbf_0.5.sav  data/svm_models/rbf
# 2  model_train_oil_vacuum_teflon_svm_rbf_0.5.sav  data/svm_models/rbf
# 3                  model_train_oil_svm_rbf_2.sav  data/svm_models/rbf
# 4           model_train_oil_vacuum_svm_rbf_2.sav  data/svm_models/rbf
# 5    model_train_oil_vacuum_teflon_svm_rbf_2.sav  data/svm_models/rbf
# ...

# %%
pd.read_csv("data/svm_models/sigmoid/results_test_oil_vacuum_teflon.csv")
# Out:
#    Unnamed: 0                         test  \
# 0           0  data/test_oil_vacuum_teflon
# 1           0  data/test_oil_vacuum_teflon
# 2           0  data/test_oil_vacuum_teflon
# 3           0  data/test_oil_vacuum_teflon
# 4           0  data/test_oil_vacuum_teflon
# 5           0  data/test_oil_vacuum_teflon
# 6           0  data/test_oil_vacuum_teflon
# 7           0  data/test_oil_vacuum_teflon
# 8           0  data/test_oil_vacuum_teflon
#
#                                                model                   kernel  \
# 0                model_train_oil_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 1         model_train_oil_vacuum_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 2  model_train_oil_vacuum_teflon_svm_sigmoid_0.5.sav  data/svm_models/sigmoid
# 3                  model_train_oil_svm_sigmoid_2.sav  data/svm_models/sigmoid
# 4           model_train_oil_vacuum_svm_sigmoid_2.sav  data/svm_models/sigmoid
# ...
